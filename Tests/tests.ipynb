# %%
import matplotlib.pyplot as plt
from perceptron import Perceptron
import numpy as np

X = np.linspace(-1, 1)

for n in range(0, 5):
    y = Perceptron.legendre_polynomial(n, X)
    plt.plot(X, y, label=r'$P_{}(x)$'.format(n))
